# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Read Data using Pandas

# %%
df = pd.read_csv("adult.data.csv")
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %% [markdown]
# ### People of race represented in the Dataset

# %%
 race_count = df["race"].value_counts()
 race_count
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %% [markdown]
# ### Average age of men

# %%
average_age_men = round(df[df['sex']== 'Male']['age'].mean(), 1)
average_age_men
# Out:
# 39.4

# %% [markdown]
# ### Percentage of people with Bachelors Education

# %%
percentage_of_bachelors = (len(df[df['education']=='Bachelors'])/len(df)) *100

# %%
percentage_of_bachelors
# Out:
# 16.44605509658794

# %% [markdown]
# ### Percentage of people with advanced education earning more than 50K

# %%
advanced_educated_people=[df[df["education"]=="Bachelors"],df[df["education"]=="Masters"],df[df["education"]=="Docatrate"]]

# %% [markdown]
# ##### number of advanced educated people

# %%
advanced_educated_people
# Out:
# [       age         workclass  fnlwgt  education  education-num  \
#  0       39         State-gov   77516  Bachelors             13
#  1       50  Self-emp-not-inc   83311  Bachelors             13
#  4       28           Private  338409  Bachelors             13
#  9       42           Private  159449  Bachelors             13
#  11      30         State-gov  141297  Bachelors             13
#  ...    ...               ...     ...        ...            ...
#  32530   35                 ?  320084  Bachelors             13
#  32531   30                 ?   33811  Bachelors             13
#  32533   54           Private  337992  Bachelors             13
#  32536   34           Private  160216  Bachelors             13
#  32538   38           Private  139180  Bachelors             13
#
#             marital-status       occupation   relationship                race  \
#  0           Never-married     Adm-clerical  Not-in-family               White
# ...

# %% [markdown]
# ##### people with advanced education earning more than 50K

# %%
advanced_educated_salary = df['salary'] == '>50K'
advanced_educated_salary
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557     True
# 32558    False
# 32559    False
# 32560     True
# Name: salary, Length: 32561, dtype: bool

# %% [markdown]
# ##### percentage of people with higher education earning more than 50K

# %%
percentage_higher_education=(len(advanced_educated_people[advanced_educated_people["salary"]==">50K"])/len(advanced_educated_people))*100
round(percentage_higher_education,1)
# Out:
# 44.9

# %% [markdown]
# ### Percentage of people without advanced education earning more than 50K

# %%
basic_educated_people = df[df["education"] != "Bachelors"]
basic_educated_people = basic_educated_people[basic_educated_people["education"] != "Masters"]
basic_educated_people = basic_educated_people[basic_educated_people["education"] != "Doctorate"]

basic_education_rich = round ( (len(basic_educated_people[basic_educated_people["salary"] == ">50K"]) / len(basic_educated_people)) * 100, 1)

# %%
basic_educated_people
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 2       38           Private  215646       HS-grad              9
# 3       53           Private  234721          11th              7
# 6       49           Private  160187           9th              5
# 7       52  Self-emp-not-inc  209642       HS-grad              9
# 10      37           Private  280464  Some-college             10
# ...    ...               ...     ...           ...            ...
# 32556   27           Private  257302    Assoc-acdm             12
# 32557   40           Private  154374       HS-grad              9
# 32558   58           Private  151910       HS-grad              9
# 32559   22           Private  201490       HS-grad              9
# 32560   52      Self-emp-inc  287927       HS-grad              9
#
#               marital-status         occupation   relationship   race     sex  \
# 2                   Divorced  Handlers-cleaners  Not-in-family  White    Male
# ...

# %%
#df.education.value_counts()

# %% [markdown]
# ### Minimum Number of hours a person works per week

# %%
min_hours=df["hours-per-week"].min()

# %%
min_hours
# Out:
# 1

# %% [markdown]
# ### Percentage of people working with minimum number of hours per week earning more than 50K

# %%
slackers = df[df["hours-per-week"] == min_hours]

# %%
percentage_people=(len(slackers[slackers["salary"]==">50K"])/len(slackers))*100

# %%
percentage_people
# Out:
# 10.0

# %% [markdown]
# ### Country with the highest percentage of people that earn more than 50K

# %% [markdown]
# ##### countries with people earning more than 50K

# %%
rich_percentages = (df[df["salary"] == ">50K"]["native-country"].value_counts() / df["native-country"].value_counts())*100
rich_percentages
# Out:
# ?                             25.042882
# Cambodia                      36.842105
# Canada                        32.231405
# China                         26.666667
# Columbia                       3.389831
# Cuba                          26.315789
# Dominican-Republic             2.857143
# Ecuador                       14.285714
# El-Salvador                    8.490566
# England                       33.333333
# France                        41.379310
# Germany                       32.116788
# Greece                        27.586207
# Guatemala                      4.687500
# Haiti                          9.090909
# Holand-Netherlands                  NaN
# Honduras                       7.692308
# Hong                          30.000000
# Hungary                       23.076923
# India                         40.000000
# Iran                          41.860465
# Ireland                       20.833333
# Italy                         34.246575
# ...

# %% [markdown]
# ##### country with the highest earnings

# %%
highest_earning_country = wealth_percentages.idxmax()
highest_earning_country
# Out:
# 'Iran'

# %% [markdown]
# ##### percentage of the country with the highest earnings

# %%
highest_earning_country_percentage = round(wealth_percentages.max(), 1)
highest_earning_country_percentage
# Out:
# 41.9

# %% [markdown]
# ### Most popular occupation for people earning more than 50K in India

# %%
indians = df[df["native-country"] == "India"]
indians = indians[indians["salary"] == ">50K"]
top_IN_occupation = indians['occupation'].value_counts().idxmax()

# %%
indians
# Out:
#        age         workclass  fnlwgt    education  education-num  \
# 11      30         State-gov  141297    Bachelors             13
# 968     48           Private  164966    Bachelors             13
# 1327    52           Private  168381      HS-grad              9
# 7258    42         State-gov  102343  Prof-school             15
# 7285    54         State-gov   93449      Masters             14
# 8124    36           Private  172104  Prof-school             15
# 9939    43       Federal-gov  325706  Prof-school             15
# 10590   35           Private   98283  Prof-school             15
# 10661   59           Private  122283  Prof-school             15
# 10736   30           Private  243190  Prof-school             15
# 11260   54           Private  225599      Masters             14
# 11384   34           Private   98283  Prof-school             15
# 13422   53           Private  366957    Bachelors             13
# ...

# %%
top_IN_occupation
# Out:
# 'Prof-specialty'
